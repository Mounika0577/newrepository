# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika0577/newrepository/blob/main/music_genre_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# lets import libraries that we will be usings
# we already have imported pandas and numpy

import matplotlib.pyplot as plt
import scipy
import librosa
import librosa.display
import IPython.display as ipd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
import pickle # model pickling for future use

# %%
# Loading dataset
# we have 2 CSVs here, one containing features for 30 sec audio file, mean & variance for diff features we have, then
# and one for 3 sec audio files. I will be using 3 sec audio
dataf = pd.read_csv("/content/features_3_sec.csv")
dataf.head()
# Out:
#             filename  length  chroma_stft_mean  ...  mfcc20_mean  mfcc20_var  label
# 0  blues.00000.0.wav   66149          0.335406  ...    -0.243027   43.771767  blues
# 1  blues.00000.1.wav   66149          0.343065  ...     5.784063   59.943081  blues
# 2  blues.00000.2.wav   66149          0.346815  ...     2.517375   33.105122  blues
# 3  blues.00000.3.wav   66149          0.363639  ...     3.630866   32.023678  blues
# 4  blues.00000.4.wav   66149          0.335579  ...     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
# removing filename column
dataf = dataf.drop(labels='filename',axis=1)

# %%
# looking into what i have 
sample_audio = "/content/pop.00003.wav"
sample, sample_rate = librosa.load(sample_audio)


ipd.Audio(sample, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample, sample_rate = librosa.load(sample_audio, sr=16000)
print(len(sample),sample_rate)
# Out:
# 480003 16000

# %%
print(type(sample),sample_rate)
sample, sample_rate = librosa.load(sample_audio, sr=16000)

# plotting raw wave Files, here it is for Pop genre
fig = plt.figure(figsize=(14,6))
ax1 = fig.add_subplot(211)
ax1.set_title("pop.00003.wav")
ax1.set_xlabel('time')
ax1.set_ylabel('Amptitude')
librosa.display.waveplot(sample)
plt.show()
# Out:
# <class 'numpy.ndarray'> 16000

# %%
# Spectrogram, we have this in images folder
# way of representing signal loudness at diff freq
# also known as Sonographs
# when data is 3D then waterfall

stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/display.py:955: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   "Trying to display complex-valued input. " "Showing magnitude instead."

# %%
stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft_db,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()

# %%
# Rolloff - feq below which a specified percentage of the total spectral lies / 85%
from sklearn.preprocessing import normalize

spectral_rolloff = librosa.feature.spectral_rolloff(sample+0.01,sr=sample_rate)[0]
plt.figure(figsize=(14,6))
librosa.display.waveplot(sample,sr=sample_rate,alpha=0.3)

# %%
# Zero crossing 
plt.figure(figsize=(14,6))
plt.plot(sample[8000:12000])
plt.grid()

# %%
#count
zero_cross = librosa.zero_crossings(sample[8000:12000],pad=False)
print("Count {}".format(sum(zero_cross)))
# Out:
# Count 498

# %%
class_list = dataf.iloc[:,-1] 
convert = LabelEncoder()

# %%
y = convert.fit_transform(class_list)
y
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
dataf.iloc[:,:-1]
# Out:
#       length  chroma_stft_mean  ...  mfcc20_mean  mfcc20_var
# 0      66149          0.335406  ...    -0.243027   43.771767
# 1      66149          0.343065  ...     5.784063   59.943081
# 2      66149          0.346815  ...     2.517375   33.105122
# 3      66149          0.363639  ...     3.630866   32.023678
# 4      66149          0.335579  ...     0.536961   29.146694
# ...      ...               ...  ...          ...         ...
# 9985   66149          0.349126  ...     1.818823   38.966969
# 9986   66149          0.372564  ...     0.428857   18.697033
# 9987   66149          0.347481  ...    -0.299545   41.586990
# 9988   66149          0.387527  ...     0.675824   12.787750
# 9989   66149          0.369293  ...    -3.412534   31.727489
#
# [9990 rows x 58 columns]

# %%
# scaling features
from sklearn.preprocessing import StandardScaler
fit = StandardScaler()
X = fit.fit_transform(np.array(dataf.iloc[:,:-1],dtype=float))

# %%
# dividing into training and test Data
X_train,x_test, Y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print(len(Y_train),len(y_test))
# Out:
# 7992 1998

# %%
# Using CNN algorithm
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# building model

model = Sequential()

model.add(Dense(512,input_shape=(X_train.shape[1],),activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10,activation='softmax'))


model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 512)               30208
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                650
# =================================================================
# Total params: 203,338
# Trainable params: 203,338
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics='accuracy')
earlystop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=10,min_delta=0.0001)
modelcheck = ModelCheckpoint('best_model.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
history = model.fit(X_train,Y_train, validation_data=(x_test,y_test), epochs=600, callbacks=[earlystop,modelcheck], batch_size=128)
# Out:
# Epoch 1/600
# 63/63 [==============================] - 1s 14ms/step - loss: 1.5960 - accuracy: 0.4258 - val_loss: 1.0473 - val_accuracy: 0.6336
#
# Epoch 00001: val_accuracy improved from -inf to 0.63363, saving model to best_model.hdf5
# Epoch 2/600
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0606 - accuracy: 0.6338 - val_loss: 0.7956 - val_accuracy: 0.7332
#
# Epoch 00002: val_accuracy improved from 0.63363 to 0.73323, saving model to best_model.hdf5
# Epoch 3/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.8737 - accuracy: 0.7043 - val_loss: 0.7215 - val_accuracy: 0.7538
#
# Epoch 00003: val_accuracy improved from 0.73323 to 0.75375, saving model to best_model.hdf5
# Epoch 4/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7520 - accuracy: 0.7514 - val_loss: 0.6606 - val_accuracy: 0.7858
#
# Epoch 00004: val_accuracy improved from 0.75375 to 0.78579, saving model to best_model.hdf5
# Epoch 5/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6560 - accuracy: 0.7890 - val_loss: 0.5483 - val_accuracy: 0.8108
#
# Epoch 00005: val_accuracy improved from 0.78579 to 0.81081, saving model to best_model.hdf5
# Epoch 6/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5928 - accuracy: 0.7989 - val_loss: 0.5170 - val_accuracy: 0.8268
#
# Epoch 00006: val_accuracy improved from 0.81081 to 0.82683, saving model to best_model.hdf5
# Epoch 7/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5254 - accuracy: 0.8268 - val_loss: 0.4861 - val_accuracy: 0.8333
#
# Epoch 00007: val_accuracy improved from 0.82683 to 0.83333, saving model to best_model.hdf5
# Epoch 8/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4837 - accuracy: 0.8378 - val_loss: 0.4617 - val_accuracy: 0.8478
#
# Epoch 00008: val_accuracy improved from 0.83333 to 0.84785, saving model to best_model.hdf5
# Epoch 9/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4260 - accuracy: 0.8575 - val_loss: 0.4218 - val_accuracy: 0.8604
#
# Epoch 00009: val_accuracy improved from 0.84785 to 0.86036, saving model to best_model.hdf5
# Epoch 10/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3781 - accuracy: 0.8741 - val_loss: 0.3910 - val_accuracy: 0.8739
#
# Epoch 00010: val_accuracy improved from 0.86036 to 0.87387, saving model to best_model.hdf5
# Epoch 11/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3544 - accuracy: 0.8849 - val_loss: 0.3943 - val_accuracy: 0.8754
#
# Epoch 00011: val_accuracy improved from 0.87387 to 0.87538, saving model to best_model.hdf5
# Epoch 12/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3338 - accuracy: 0.8913 - val_loss: 0.3909 - val_accuracy: 0.8709
#
# Epoch 00012: val_accuracy did not improve from 0.87538
# Epoch 13/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2904 - accuracy: 0.9032 - val_loss: 0.3645 - val_accuracy: 0.8819
#
# Epoch 00013: val_accuracy improved from 0.87538 to 0.88188, saving model to best_model.hdf5
# Epoch 14/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2764 - accuracy: 0.9059 - val_loss: 0.3700 - val_accuracy: 0.8829
#
# Epoch 00014: val_accuracy improved from 0.88188 to 0.88288, saving model to best_model.hdf5
# Epoch 15/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2558 - accuracy: 0.9178 - val_loss: 0.3556 - val_accuracy: 0.8844
#
# Epoch 00015: val_accuracy improved from 0.88288 to 0.88438, saving model to best_model.hdf5
# Epoch 16/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2284 - accuracy: 0.9252 - val_loss: 0.3307 - val_accuracy: 0.8884
#
# Epoch 00016: val_accuracy improved from 0.88438 to 0.88839, saving model to best_model.hdf5
# Epoch 17/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2069 - accuracy: 0.9311 - val_loss: 0.3531 - val_accuracy: 0.8929
#
# Epoch 00017: val_accuracy improved from 0.88839 to 0.89289, saving model to best_model.hdf5
# Epoch 18/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.2031 - accuracy: 0.9323 - val_loss: 0.3336 - val_accuracy: 0.8944
#
# Epoch 00018: val_accuracy improved from 0.89289 to 0.89439, saving model to best_model.hdf5
# Epoch 19/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1940 - accuracy: 0.9383 - val_loss: 0.3217 - val_accuracy: 0.9024
#
# Epoch 00019: val_accuracy improved from 0.89439 to 0.90240, saving model to best_model.hdf5
# Epoch 20/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1813 - accuracy: 0.9402 - val_loss: 0.3437 - val_accuracy: 0.8964
#
# Epoch 00020: val_accuracy did not improve from 0.90240
# Epoch 21/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1573 - accuracy: 0.9463 - val_loss: 0.3357 - val_accuracy: 0.8979
#
# Epoch 00021: val_accuracy did not improve from 0.90240
# Epoch 22/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1585 - accuracy: 0.9479 - val_loss: 0.3195 - val_accuracy: 0.9034
#
# Epoch 00022: val_accuracy improved from 0.90240 to 0.90340, saving model to best_model.hdf5
# Epoch 23/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1487 - accuracy: 0.9511 - val_loss: 0.3495 - val_accuracy: 0.8959
#
# Epoch 00023: val_accuracy did not improve from 0.90340
# Epoch 24/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1311 - accuracy: 0.9588 - val_loss: 0.3161 - val_accuracy: 0.9074
#
# Epoch 00024: val_accuracy improved from 0.90340 to 0.90741, saving model to best_model.hdf5
# Epoch 25/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1284 - accuracy: 0.9553 - val_loss: 0.3264 - val_accuracy: 0.9059
#
# Epoch 00025: val_accuracy did not improve from 0.90741
# Epoch 26/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1331 - accuracy: 0.9570 - val_loss: 0.3190 - val_accuracy: 0.9069
#
# Epoch 00026: val_accuracy did not improve from 0.90741
# Epoch 27/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1283 - accuracy: 0.9615 - val_loss: 0.2951 - val_accuracy: 0.9199
#
# Epoch 00027: val_accuracy improved from 0.90741 to 0.91992, saving model to best_model.hdf5
# Epoch 28/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.1285 - accuracy: 0.9591 - val_loss: 0.3129 - val_accuracy: 0.9074
#
# Epoch 00028: val_accuracy did not improve from 0.91992
# Epoch 29/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1068 - accuracy: 0.9675 - val_loss: 0.3173 - val_accuracy: 0.9154
#
# Epoch 00029: val_accuracy did not improve from 0.91992
# Epoch 30/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1041 - accuracy: 0.9668 - val_loss: 0.3003 - val_accuracy: 0.9204
#
# Epoch 00030: val_accuracy improved from 0.91992 to 0.92042, saving model to best_model.hdf5
# Epoch 31/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.1071 - accuracy: 0.9657 - val_loss: 0.3179 - val_accuracy: 0.9154
#
# Epoch 00031: val_accuracy did not improve from 0.92042
# Epoch 32/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0958 - accuracy: 0.9698 - val_loss: 0.2893 - val_accuracy: 0.9154
#
# Epoch 00032: val_accuracy did not improve from 0.92042
# Epoch 33/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0879 - accuracy: 0.9733 - val_loss: 0.3258 - val_accuracy: 0.9109
#
# Epoch 00033: val_accuracy did not improve from 0.92042
# Epoch 34/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0889 - accuracy: 0.9710 - val_loss: 0.3045 - val_accuracy: 0.9209
#
# Epoch 00034: val_accuracy improved from 0.92042 to 0.92092, saving model to best_model.hdf5
# Epoch 35/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0812 - accuracy: 0.9740 - val_loss: 0.3422 - val_accuracy: 0.9109
#
# Epoch 00035: val_accuracy did not improve from 0.92092
# Epoch 36/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0877 - accuracy: 0.9728 - val_loss: 0.3375 - val_accuracy: 0.9124
#
# Epoch 00036: val_accuracy did not improve from 0.92092
# Epoch 37/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0741 - accuracy: 0.9762 - val_loss: 0.3604 - val_accuracy: 0.9099
#
# Epoch 00037: val_accuracy did not improve from 0.92092
# Epoch 38/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0869 - accuracy: 0.9737 - val_loss: 0.2994 - val_accuracy: 0.9244
#
# Epoch 00038: val_accuracy improved from 0.92092 to 0.92442, saving model to best_model.hdf5
# Epoch 39/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0744 - accuracy: 0.9789 - val_loss: 0.3393 - val_accuracy: 0.9224
#
# Epoch 00039: val_accuracy did not improve from 0.92442
# Epoch 40/600
# 63/63 [==============================] - 1s 10ms/step - loss: 0.0787 - accuracy: 0.9742 - val_loss: 0.3418 - val_accuracy: 0.9154
#
# Epoch 00040: val_accuracy did not improve from 0.92442
# Epoch 41/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0786 - accuracy: 0.9741 - val_loss: 0.3208 - val_accuracy: 0.9219
#
# Epoch 00041: val_accuracy did not improve from 0.92442
# Epoch 42/600
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0750 - accuracy: 0.9767 - val_loss: 0.3174 - val_accuracy: 0.9204
#
# Epoch 00042: val_accuracy did not improve from 0.92442
# Epoch 00042: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend()
pyplot.show()

# %%
#from keras.models import load_model
#Model = load_model("./best_model.hdf5")
test_loss, test_accuracy = model.evaluate(x_test,y_test,batch_size=128)
print("Test loss : ",test_loss)
print("\nBest test accuracy : ",test_accuracy*100)
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3174 - accuracy: 0.9204
# Test loss :  0.3173644542694092
#
# Best test accuracy :  92.04204082489014
